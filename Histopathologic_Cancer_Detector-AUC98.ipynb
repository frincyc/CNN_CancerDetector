# %% [markdown]
# # Histopathologic Cancer Detector

# %%
#Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sn

import shutil, os

from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D

from keras.layers import Flatten
from keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
# Out:
# Using TensorFlow backend.

# %%
#Initializing Constants

IMG_HEIGHT = 96
IMG_WIDTH = 96
IMG_CHANNELS = 3

# %%
#Reading the data labels from CSV

base_dir = '..\Histopathologic_Cancer_Detection'
dataset = pd.read_csv(base_dir+'\\train_labels.csv')
X = dataset.iloc[:,0].values
y = dataset.iloc[:,1].values

# %%
#Visualizing training image samples

fig = plt.figure(figsize = (20,8))
index = 1
for i in np.random.randint(low = 0, high = dataset.shape[0], size = 10):
    file = os.path.join(os.path.join(base_dir,'train'),dataset.iloc[i]['id'] + '.tif')
    img=mpimg.imread(file)
    ax = fig.add_subplot(2, 5, index)
    ax.imshow(img, cmap = 'gray')
    index = index + 1
    color = ['green' if dataset.iloc[i].label == 1 else 'red'][0]
    ax.set_title(dataset.iloc[i].label, fontsize = 18, color = color)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 1 - Data Preparation

# %%
#Encoding the categorical variables

from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
#Distribution of Classes

dataset['label'].value_counts()
# Out:
# 0    130908
# 1     89117
# Name: label, dtype: int64

# %%
#Finding the Class distribution ratio in dataset

data_distribution = dataset[dataset['label']==1].count()/dataset[dataset['label']==0].count()

# %%
#Splitting 10% as test set from the original dataset 

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0, stratify = y)

# %%
#Splitting 10% from the dataset as validation set 

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = (0.1/0.9), random_state = 0, stratify = y_train)

# %%
train_set_distribution = np.count_nonzero(y_train==1)/(len(y_train) - np.count_nonzero(y_train==1))
print('Training Set Distribution Ratio: {:.2f}'.format(train_set_distribution))
test_set_distribution = np.count_nonzero(y_test==1)/(len(y_test) - np.count_nonzero(y_test==1))
print('Test Set Distribution Ratio: {:.2f}'.format(test_set_distribution))
# Out:
# Training Set Distribution Ratio: 0.68
# Test Set Distribution Ratio: 0.68

# %%
print('Size of training set:', len(X_train))
print('Size of validation set:', len(X_val))
print('Size of test set:', len(X_test))
# Out:
# Size of training set: 176019
# Size of validation set: 22003
# Size of test set: 22003

# %%
#Creating new dataset folder path for input

base_dest = os.path.join(base_dir,'dataset')

# %%
#Creating dataset folder

os.mkdir(base_dest)

# %%
#Creating new folder paths for training input

source = os.path.join(base_dir,'train')
train_dest = os.path.join(base_dest,'train')
val_dest = os.path.join(base_dest,'val')
test_dest = os.path.join(base_dest,'test')

# %%
#Creating folders for train/val/test

os.mkdir(train_dest)
os.mkdir(val_dest)
os.mkdir(test_dest)

# %%
def copy_to_classfolders(source,dest,X,y):
    
    '''
    Function to copy data images to train/validation/test folders according to their classes
    '''
    
    #Creating new folders for each class
    class_zero = os.path.join(dest,'Class_NoTumor')
    class_one = os.path.join(dest,'Class_Tumor')
    os.mkdir(class_zero)
    os.mkdir(class_one)

    #Copying training images according to its class
    for image in X:
        selected_image = image + '.tif'
        source_file = os.path.join(source,selected_image)
        index = np.where(X == image)
        if y[index] == 0:
            dest_file = os.path.join(class_zero,selected_image)
        elif y[index] == 1:
            dest_file = os.path.join(class_one,selected_image)
        shutil.copyfile(source_file, dest_file)

# %%
#Copying all images according to the train.val.test split

copy_to_classfolders(source, train_dest, X_train, y_train)
copy_to_classfolders(source, val_dest, X_val, y_val)
copy_to_classfolders(source, test_dest, X_test, y_test)

# %% [markdown]
# ## Part 2 - Building the CNN Model

# %%
# Initialising the CNN
classifier = Sequential()

# %%
#Initializing constants for building the model

FILTER_1 = 16
FILTER_2 = 32
FILTER_3 = 64
FILTER_4 = 128

KERNEL_SIZE = (3,3)
DROPOUT_RATE = 0.3
POOL_SIZE = (3,3)

TRAIN_BATCH_SIZE = 256
VAL_BATCH_SIZE = 64
TEST_BATCH_SIZE = 1

# %%
# Step 1 - First Convolution layer - Dropout and Max Pooling

classifier.add(Convolution2D(filters = FILTER_1, kernel_size = KERNEL_SIZE, padding = 'same', input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS), activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_1, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_1, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Dropout(DROPOUT_RATE))
classifier.add(MaxPooling2D(pool_size = POOL_SIZE))

# %%
# Step 2 - Second Convolution layer - Dropout and Max Pooling

classifier.add(Convolution2D(filters = FILTER_2, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_2, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_2, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Dropout(DROPOUT_RATE))
classifier.add(MaxPooling2D(pool_size = POOL_SIZE))

# %%
# Step 3 - Third Convolution layer -  Dropout and Max Pooling

classifier.add(Convolution2D(filters = FILTER_3, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_3, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_3, kernel_size = KERNEL_SIZE, padding = 'same', activation = 'relu'))
classifier.add(Dropout(DROPOUT_RATE))
classifier.add(MaxPooling2D(pool_size = POOL_SIZE))

# %%
# Step 4 - Fourth Convolution layer - Dropout

classifier.add(Convolution2D(filters = FILTER_4, kernel_size = KERNEL_SIZE, padding = 'same',activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_4, kernel_size = KERNEL_SIZE, padding = 'same',activation = 'relu'))
classifier.add(Convolution2D(filters = FILTER_4, kernel_size = KERNEL_SIZE, padding = 'same',activation = 'relu'))
classifier.add(Dropout(DROPOUT_RATE))

# %%
# Step 6 - Flattening

classifier.add(Flatten())

# %%
# Step 7 - Full connection

classifier.add(Dense(output_dim = 128, activation = 'relu'))
classifier.add(Dropout(DROPOUT_RATE))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))
# Out:
# C:\Anaconda\envs\python36\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda\envs\python36\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`
#   """

# %%
classifier.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 16)        448
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 16)        2320
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 96, 96, 16)        2320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 96, 96, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 3, 3, 128)         73856
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               147584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 637,313
# Trainable params: 637,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the CNN using Adam optimizer

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Part 3 - Data Generation

# %%
#Generating batches of tensor image data for train/val/test images

from keras.preprocessing.image import ImageDataGenerator

data_gen = ImageDataGenerator(rescale = 1./255)

training_set = data_gen.flow_from_directory(train_dest,
                                                 target_size = (IMG_HEIGHT,IMG_WIDTH),
                                                 batch_size = TRAIN_BATCH_SIZE,
                                                 class_mode = 'binary')

val_set = data_gen.flow_from_directory(val_dest,
                                            target_size = (IMG_HEIGHT,IMG_WIDTH),
                                            batch_size = VAL_BATCH_SIZE,
                                            class_mode = 'binary',
                                           shuffle=False)

test_set = data_gen.flow_from_directory(test_dest,
                                            target_size = (IMG_HEIGHT,IMG_WIDTH),
                                            batch_size = TEST_BATCH_SIZE,
                                            class_mode = 'binary',
                                           shuffle=False)
# Out:
# Found 176019 images belonging to 2 classes.
# Found 22003 images belonging to 2 classes.
# Found 22003 images belonging to 2 classes.

# %% [markdown]
# ## Part 4: Learning on Training Data

# %%
#Setting GPU session

from keras import backend as K
cfg = K.tf.ConfigProto()
cfg.gpu_options.allow_growth = True
K.set_session(K.tf.Session(config=cfg))

# %%
#Variables for training the model

model_checkpoint = ModelCheckpoint(base_dir+'\\model.h5', monitor='val_acc', verbose=1, 
                            save_best_only=True, mode='max')
csv_logger = CSVLogger(base_dir+'\\Log.log')
early_stopping = EarlyStopping(monitor = 'val_acc',min_delta = 0.000001,patience= 6, verbose = 1, mode = 'max' )

# %%
#Learning on the training set

history = classifier.fit_generator(training_set,
                         steps_per_epoch = np.ceil(len(X_train)/training_set.batch_size),
                         epochs = 30,
                         validation_data = val_set,
                         validation_steps = np.ceil(len(X_val)/val_set.batch_size),
                                  callbacks= [model_checkpoint, early_stopping, csv_logger])
# Out:
# Epoch 1/30
# 688/688 [==============================] - 698s 1s/step - loss: 0.4996 - acc: 0.7496 - val_loss: 0.4673 - val_acc: 0.8023
#
# Epoch 00001: val_acc improved from -inf to 0.80230, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 2/30
# 688/688 [==============================] - 705s 1s/step - loss: 0.3696 - acc: 0.8411 - val_loss: 0.3664 - val_acc: 0.8461
#
# Epoch 00002: val_acc improved from 0.80230 to 0.84607, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 3/30
# 688/688 [==============================] - 714s 1s/step - loss: 0.3154 - acc: 0.8671 - val_loss: 0.3238 - val_acc: 0.8592
#
# Epoch 00003: val_acc improved from 0.84607 to 0.85916, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 4/30
# 688/688 [==============================] - 687s 998ms/step - loss: 0.2903 - acc: 0.8797 - val_loss: 0.3173 - val_acc: 0.8717
#
# Epoch 00004: val_acc improved from 0.85916 to 0.87174, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 5/30
# 688/688 [==============================] - 659s 958ms/step - loss: 0.2665 - acc: 0.8911 - val_loss: 0.2848 - val_acc: 0.8832
#
# Epoch 00005: val_acc improved from 0.87174 to 0.88324, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 6/30
# 688/688 [==============================] - 661s 961ms/step - loss: 0.2459 - acc: 0.9013 - val_loss: 0.2538 - val_acc: 0.8997
#
# Epoch 00006: val_acc improved from 0.88324 to 0.89970, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 7/30
# 688/688 [==============================] - 672s 977ms/step - loss: 0.2288 - acc: 0.9092 - val_loss: 0.2406 - val_acc: 0.9032
#
# Epoch 00007: val_acc improved from 0.89970 to 0.90320, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 8/30
# 688/688 [==============================] - 665s 967ms/step - loss: 0.2202 - acc: 0.9130 - val_loss: 0.2825 - val_acc: 0.8823
#
# Epoch 00008: val_acc did not improve from 0.90320
# Epoch 9/30
# 688/688 [==============================] - 736s 1s/step - loss: 0.2061 - acc: 0.9198 - val_loss: 0.2188 - val_acc: 0.9154
#
# Epoch 00009: val_acc improved from 0.90320 to 0.91542, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 10/30
# 688/688 [==============================] - 669s 972ms/step - loss: 0.1994 - acc: 0.9226 - val_loss: 0.2174 - val_acc: 0.9172
#
# Epoch 00010: val_acc improved from 0.91542 to 0.91719, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 11/30
# 688/688 [==============================] - 689s 1s/step - loss: 0.1916 - acc: 0.9263 - val_loss: 0.2271 - val_acc: 0.9092
#
# Epoch 00011: val_acc did not improve from 0.91719
# Epoch 12/30
# 688/688 [==============================] - 692s 1s/step - loss: 0.1886 - acc: 0.9275 - val_loss: 0.2657 - val_acc: 0.8857
#
# Epoch 00012: val_acc did not improve from 0.91719
# Epoch 13/30
# 688/688 [==============================] - 669s 972ms/step - loss: 0.1832 - acc: 0.9296 - val_loss: 0.3101 - val_acc: 0.8764
#
# Epoch 00013: val_acc did not improve from 0.91719
# Epoch 14/30
# 688/688 [==============================] - 665s 967ms/step - loss: 0.1778 - acc: 0.9319 - val_loss: 0.2133 - val_acc: 0.9165
#
# Epoch 00014: val_acc did not improve from 0.91719
# Epoch 15/30
# 688/688 [==============================] - 669s 973ms/step - loss: 0.1733 - acc: 0.9340 - val_loss: 0.2032 - val_acc: 0.9196
#
# Epoch 00015: val_acc improved from 0.91719 to 0.91965, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 16/30
# 688/688 [==============================] - 676s 982ms/step - loss: 0.1704 - acc: 0.9353 - val_loss: 0.2045 - val_acc: 0.9196
#
# Epoch 00016: val_acc did not improve from 0.91965
# Epoch 17/30
# 688/688 [==============================] - 666s 968ms/step - loss: 0.1678 - acc: 0.9364 - val_loss: 0.2188 - val_acc: 0.9148
#
# Epoch 00017: val_acc did not improve from 0.91965
# Epoch 18/30
# 688/688 [==============================] - 647s 940ms/step - loss: 0.1601 - acc: 0.9399 - val_loss: 0.1922 - val_acc: 0.9264
#
# Epoch 00018: val_acc improved from 0.91965 to 0.92642, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 19/30
# 688/688 [==============================] - 624s 907ms/step - loss: 0.1600 - acc: 0.9393 - val_loss: 0.1883 - val_acc: 0.9265
#
# Epoch 00019: val_acc improved from 0.92642 to 0.92651, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 20/30
# 688/688 [==============================] - 630s 916ms/step - loss: 0.1550 - acc: 0.9419 - val_loss: 0.1858 - val_acc: 0.9302
#
# Epoch 00020: val_acc improved from 0.92651 to 0.93019, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 21/30
# 688/688 [==============================] - 636s 925ms/step - loss: 0.1539 - acc: 0.9419 - val_loss: 0.1953 - val_acc: 0.9256
#
# Epoch 00021: val_acc did not improve from 0.93019
# Epoch 22/30
# 688/688 [==============================] - 646s 939ms/step - loss: 0.1525 - acc: 0.9426 - val_loss: 0.1817 - val_acc: 0.9313
#
# Epoch 00022: val_acc improved from 0.93019 to 0.93128, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 23/30
# 688/688 [==============================] - 653s 949ms/step - loss: 0.1526 - acc: 0.9424 - val_loss: 0.1782 - val_acc: 0.9355
#
# Epoch 00023: val_acc improved from 0.93128 to 0.93551, saving model to D:\Manju - CS\Machine Learning\Histopathologic_Cancer_Detection\model_14.h5
# Epoch 24/30
# 688/688 [==============================] - 665s 967ms/step - loss: 0.1447 - acc: 0.9452 - val_loss: 0.1930 - val_acc: 0.9223
#
# Epoch 00024: val_acc did not improve from 0.93551
# Epoch 25/30
# 688/688 [==============================] - 685s 996ms/step - loss: 0.1438 - acc: 0.9462 - val_loss: 0.2321 - val_acc: 0.9039
#
# Epoch 00025: val_acc did not improve from 0.93551
# Epoch 26/30
# 688/688 [==============================] - 680s 988ms/step - loss: 0.1421 - acc: 0.9468 - val_loss: 0.1887 - val_acc: 0.9276
#
# Epoch 00026: val_acc did not improve from 0.93551
# Epoch 27/30
# 688/688 [==============================] - 663s 964ms/step - loss: 0.1400 - acc: 0.9474 - val_loss: 0.2055 - val_acc: 0.9216
#
# Epoch 00027: val_acc did not improve from 0.93551
# Epoch 28/30
# 688/688 [==============================] - 661s 961ms/step - loss: 0.1377 - acc: 0.9484 - val_loss: 0.1843 - val_acc: 0.9306
#
# Epoch 00028: val_acc did not improve from 0.93551
# Epoch 29/30
# 688/688 [==============================] - 682s 991ms/step - loss: 0.1373 - acc: 0.9485 - val_loss: 0.1815 - val_acc: 0.9314
#
# Epoch 00029: val_acc did not improve from 0.93551
# Epoch 00029: early stopping

# %% [markdown]
# ## Part 5: Model Assessment

# %%
# Plot training & validation accuracy values

plt.plot(history.history['acc'], c = 'red')
plt.plot(history.history['val_acc'], c = 'blue')
plt.title('Training Vs. Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values

plt.plot(history.history['loss'], c = 'red')
plt.plot(history.history['val_loss'], 'blue')
plt.title('Training Vs. Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
#Loading back the trained model for prediction

classifier.load_weights(base_dir+'\\model.h5')

# %%
#Evaluating Generator on the val set to find Accuracy/Loss

score = classifier.evaluate_generator(val_set, steps = len(X_val),verbose = 1, workers= 1, pickle_safe=False)
print('Performance of generated classifier:\n ',score)
# Out:
# C:\Anaconda\envs\python36\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `evaluate_generator` call to the Keras 2 API: `evaluate_generator(<keras_pre..., steps=22003, verbose=1, workers=1, use_multiprocessing=False)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# 22003/22003 [==============================] - 2535s 115ms/step
# Performance of generated classifier:
#   [0.17813773885836048, 0.9355259764273797]

# %% [markdown]
# ## Part 6: Performance Measurement

# %%
#Predict on the test set

y_pred = classifier.predict_generator(test_set, steps = len(X_test), verbose = 1, workers = 1)
y_true = test_set.classes
# Out:
# 22003/22003 [==============================] - 2950s 134ms/step

# %%
## Finding ROC Score

from sklearn.metrics import roc_auc_score, roc_curve, auc
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_true, y_pred)
auc_keras = auc(fpr_keras, tpr_keras)
print('Area under ROC curve: {:.2f}'.format(auc_keras))
# Out:
# Area under ROC curve: 0.98

# %%
#Plotting ROC Curve

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='area = {:.3f}'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
#Confusion matrix using sklearn

from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_true, y_pred[:,0].round())
cm_plot_labels = ['0 - No Tumor', '1 - Tumor']

# %%
#Plot Confusion Matrix

ax = plt.subplot()
df_cm = pd.DataFrame(cm, range(2),range(2)) 
sn.heatmap(df_cm, annot=True , ax = ax, fmt = 'g')# font size
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(cm_plot_labels); 
ax.yaxis.set_ticklabels(cm_plot_labels);

# %%
#Printing Classification Report

from sklearn.metrics import classification_report
report = classification_report(y_true, y_pred[:,0].round(), target_names=cm_plot_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
# 0 - No Tumor       0.93      0.97      0.95     13091
#    1 - Tumor       0.95      0.89      0.92      8912
#
#    micro avg       0.94      0.94      0.94     22003
#    macro avg       0.94      0.93      0.93     22003
# weighted avg       0.94      0.94      0.93     22003

# %%
#Finding accuracy on the test data

print("Accuracy of predictions: {:.2f} %".format(accuracy_score(y_true, y_pred[:,0].round())*100))
# Out:
# Accuracy of predictions: 93.52 %
